# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8



version = '1.20.4' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'vanilla'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]


if colabconfig["server_version"] < "1.17":
    #en la segunda linea de este if puedes cambiar la version de java que quieres instalar, (openjdk-𝟠-jre- (En el 8 puedes cambiarlo si lo necesitas dependiendo del error que te salga))
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-8-jre-headless &>/dev/null') and print("OpenJDK 8 installed") or print("Failed to install OpenJDK 8.")
# Instalar OpenJDK 17 si la version de Minecraft es 1.17 o superior
else:
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-17-jre-headless &>/dev/null') and print("OpenJDK 17 installed") or print("Failed to install OpenJDK 17.")

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2BmeNlA1JSg7IXvS8cU72Gn5Fkm_7u5Lf5jAuf8ex3DDvxQmg" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui
    
    
elif tunnel_service == "zerotier":
    # Instalar ZeroTier
    # !curl -s https://install.zerotier.com | sudo bash

    # Ingresar a tu red de ZeroTier
    zerotier_network_id = "YOUR_NETWORK_ID"  # Remplaza con tu id de red de ZeroTier
    # !sudo zerotier-cli join $zerotier_network_id

    # Esperar a que ZeroTier se una a la red
    import time
    time.sleep(120)  # Aumentalo si es neceasrio

    #Chequea el estado de ZeroTier
    # !sudo zerotier-cli status


print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto



# asdasdsasdasasdASDAasdasdasd
# asdasdasdasdasdasd
# asdasdas dasdklj prueba 123asdas
# asdasasd 10:36asdasdasdasdasd asdasdasd
# asdasdasdasd dasdasasd
# asdasdasdasdasd
# asdasdasasdasd
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	ops.json	   vanilla.jar	   world
# banned-players.json  libraries	server.properties  versions
# colabconfig.json     logs	usercache.json	   whitelist.json
# Failed to install OpenJDK 17.
# Reading package lists...Usando ngrok
#
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   ca-certificates-java java-common libpcsclite1
# Suggested packages:
#   default-jre pcscd libnss-mdns fonts-dejavu-extra fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   ca-certificates-java java-common libpcsclite1 openjdk-17-jre-headless
# 0 upgraded, 4 newly installed, 0 to remove and 37 not upgraded.
# Need to get 43.7 MB of archives.
# After this operation, 193 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 2.tcp.ngrok.io:15245
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Starting net.minecraft.server.Main
# [05:39:58] [ServerMain/INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [05:40:00] [ServerMain/INFO]: Loaded 7 recipes
# [05:40:00] [ServerMain/INFO]: Loaded 1271 advancements
# [05:40:00] [Server thread/INFO]: Starting minecraft server version 1.20.4
# [05:40:00] [Server thread/INFO]: Loading properties
# [05:40:00] [Server thread/INFO]: Default game type: SURVIVAL
# [05:40:00] [Server thread/INFO]: Generating keypair
# [05:40:01] [Server thread/INFO]: Starting Minecraft server on *:25565
# [05:40:01] [Server thread/INFO]: Using epoll channel type
# [05:40:01] [Server thread/INFO]: Preparing level "world"
# [05:40:03] [Server thread/INFO]: Preparing start region for dimension minecraft:overworld
# [05:40:05] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [05:40:05] [Worker-Main-2/INFO]: Preparing spawn area: 0%
# [05:40:05] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [05:40:05] [Worker-Main-2/INFO]: Preparing spawn area: 0%
# [05:40:05] [Worker-Main-2/INFO]: Preparing spawn area: 0%
# [05:40:06] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [05:40:06] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [05:40:07] [Worker-Main-3/INFO]: Preparing spawn area: 1%
# [05:40:07] [Worker-Main-1/INFO]: Preparing spawn area: 35%
# [05:40:08] [Server thread/INFO]: Time elapsed: 4293 ms
# [05:40:08] [Server thread/INFO]: Done (6.873s)! For help, type "help"
# [05:40:49] [User Authenticator #1/INFO]: UUID of player Juanetoh is 446b1f3f-0942-484f-aad4-88db3868617d
# [05:40:50] [Server thread/INFO]: Juanetoh[/[0:0:0:0:0:0:0:1%0]:49930] logged in with entity id 308 at (74.16444151714887, -18.0, -1052.300000011921)
# [05:40:50] [Server thread/INFO]: Juanetoh joined the game
# [05:41:51] [User Authenticator #2/INFO]: UUID of player PriscilaAliceMia is d4f6cf9c-199d-4557-b529-01de42f645bc
# [05:41:52] [Server thread/INFO]: PriscilaAliceMia[/[0:0:0:0:0:0:0:1%0]:53854] logged in with entity id 715 at (74.87521283857949, -18.0, -1052.3487187667092)
# [05:41:52] [Server thread/INFO]: PriscilaAliceMia joined the game
# [05:45:55] [Server thread/INFO]: <Juanetoh> wtf
# [05:45:57] [Server thread/INFO]: <Juanetoh> murio discord?
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [05:52:41] [Server thread/INFO]: <Juanetoh> pq dicen que terminemos? :C tite
# [05:53:01] [Server thread/INFO]: <Juanetoh> si entendí
# [05:53:04] [Server thread/INFO]: <Juanetoh> xd
# [05:53:26] [Server thread/INFO]: <Juanetoh> :v
# [05:53:30] [Server thread/INFO]: <Juanetoh> solo hago drama
# [05:53:31] [Server thread/INFO]: <Juanetoh> xdd
# [05:54:02] [Server thread/INFO]: <Juanetoh> XD
# [05:55:48] [Server thread/INFO]: <Juanetoh> oye bb
# [05:55:52] [Server thread/INFO]: <PriscilaAliceMia> mua mua mua
# [05:55:54] [Server thread/INFO]: <Juanetoh> mua muama
# [05:56:06] [Server thread/INFO]: <Juanetoh> es muy lindo escucharte, ahorita hablo xd
# [05:56:11] [Server thread/INFO]: <Juanetoh> es que mi sobrina esta mimiendo
# [05:56:20] [Server thread/INFO]: <PriscilaAliceMia> awww ntp bb
# [05:56:26] [Server thread/INFO]: <Juanetoh> yy
# [05:56:27] [Server thread/INFO]: <Juanetoh> hacemos
# [05:56:28] [Server thread/INFO]: <Juanetoh> lode
# [05:56:30] [Server thread/INFO]: <Juanetoh> mover las cosas?
# [05:56:31] [Server thread/INFO]: <Juanetoh> o al rato
# [05:56:34] [Server thread/INFO]: <Juanetoh> o quieres terminar de minar?
# [05:56:35] [Server thread/INFO]: <Juanetoh> xd
# [05:56:49] [Server thread/INFO]: <PriscilaAliceMia> vamos arriba? quiero ir a ver las vaquitas
# [05:56:59] [Server thread/INFO]: <Juanetoh> *me disfrazo de vaquita
# [05:57:22] [Server thread/INFO]: <PriscilaAliceMia> ayyy
# [05:57:25] [Server thread/INFO]: <Juanetoh> a
# [05:57:33] [Server thread/INFO]: <Juanetoh> no mi amor
# [05:57:36] [Server thread/INFO]: <Juanetoh> no veas abajito
# [05:57:38] [Server thread/INFO]: <Juanetoh> te amo
# [05:57:41] [Server thread/INFO]: <Juanetoh> siempre arriba ve
# [05:57:48] [Server thread/INFO]: <Juanetoh> no tan arriba
# [05:57:48] [Server thread/INFO]: <Juanetoh> XD
# [05:57:50] [Server thread/INFO]: <Juanetoh> mirame a mi
# [05:57:56] [Server thread/INFO]: <Juanetoh> alavrg
# [05:58:06] [Server thread/INFO]: <Juanetoh> vamos arriba entonces mi amor?
# [05:58:14] [Server thread/INFO]: <Juanetoh> y despues movemos las cosas?
# [05:58:20] [Server thread/INFO]: <PriscilaAliceMia> chi, como hago?
# [05:58:27] [Server thread/INFO]: <Juanetoh> como ya no me acuerdo de como llegamos
# [05:58:28] [Server thread/INFO]: <Juanetoh> XD
# [05:58:35] [Server thread/INFO]: <PriscilaAliceMia> oh si tomaste capturas de moon? de nuestras cosas
# [05:58:35] [Server thread/INFO]: <Juanetoh> hacemos un pinche escalerio hacia arriba
# [05:58:45] [Server thread/INFO]: <Juanetoh> necesito que estemos los 2 alla
# [05:59:20] [Server thread/INFO]: <Juanetoh> yo soy tu sorpresota
# [05:59:21] [Server thread/INFO]: <Juanetoh> muajaja
# [05:59:35] [Server thread/INFO]: <Juanetoh> xd
# [05:59:37] [Server thread/INFO]: <Juanetoh> fornait
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [05:59:54] [Server thread/INFO]: <Juanetoh> a
# [05:59:57] [Server thread/INFO]: <Juanetoh> que le pasa a
# [06:01:10] [Server thread/INFO]: <PriscilaAliceMia> como vuelvo??? a la casa???
# [06:01:32] [Server thread/INFO]: <Juanetoh> vente mi amor
# [06:01:43] [Server thread/INFO]: <Juanetoh> amor
# [06:02:01] [Server thread/INFO]: <Juanetoh> pero
# [06:02:04] [Server thread/INFO]: <Juanetoh> es mi recuerdito
# [06:04:11] [Server thread/INFO]: <Juanetoh> xd
# [06:04:12] [Server thread/INFO]: <Juanetoh> jajaj
# [06:04:25] [Server thread/INFO]: <Juanetoh> ooh
# [06:04:26] [Server thread/INFO]: <Juanetoh> ahuevo
# [06:04:28] [Server thread/INFO]: <Juanetoh> lava
# [06:04:51] [Server thread/INFO]: <Juanetoh> fuera joto
# [06:04:53] [Server thread/INFO]: <Juanetoh> de mi novia
# [06:05:24] [Server thread/INFO]: Juanetoh has made the advancement [Hot Stuff]
# [06:05:38] [Server thread/INFO]: <Juanetoh> mira guapa
# [06:05:42] [Server thread/INFO]: <Juanetoh> así se hace obsidiana
# [06:06:21] [Server thread/INFO]: <Juanetoh> eh
# [06:06:22] [Server thread/INFO]: <Juanetoh> o sea
# [06:06:26] [Server thread/INFO]: <Juanetoh> que no estarías conmigo
# [06:06:28] [Server thread/INFO]: <Juanetoh> sino estas pendeja?
# [06:06:29] [Server thread/INFO]: <Juanetoh> :c
# [06:06:58] [Server thread/INFO]: <Juanetoh> pero no eres pendeja
# [06:06:58] [Server thread/INFO]: <Juanetoh> <3
# [06:07:26] [Server thread/INFO]: <Juanetoh> voy
# [06:07:57] [Server thread/INFO]: <Juanetoh> tienes comida?
# [06:08:02] [Server thread/INFO]: <Juanetoh> ten
# [06:08:16] [Server thread/INFO]: <Juanetoh> comele
# [06:09:39] [Server thread/INFO]: <Juanetoh> fiu fiuf ifu
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [06:11:04] [Server thread/INFO]: <Juanetoh> ya así
# [06:11:05] [Server thread/INFO]: <Juanetoh> perdón xd
# [06:11:11] [Server thread/INFO]: <Juanetoh> es que es pa ir al "inframundo"
# [06:13:53] [Server thread/INFO]: <Juanetoh> a ver guapa
# [06:14:40] [Server thread/INFO]: <Juanetoh> lo quieres?
# [06:15:33] [Server thread/INFO]: <Juanetoh> amonos mi amor
# [06:15:38] [Server thread/INFO]: <Juanetoh> xd
# [06:16:45] [Server thread/INFO]: <Juanetoh> estan llorando por ti
# [06:18:17] [Server thread/INFO]: Juanetoh was shot by Skeleton
# [06:18:21] [Server thread/INFO]: [Juanetoh: Teleported Juanetoh to PriscilaAliceMia]
# [06:18:24] [Server thread/INFO]: PriscilaAliceMia was shot by Skeleton
# [06:18:40] [Server thread/INFO]: [PriscilaAliceMia: Teleported PriscilaAliceMia to Juanetoh]
# [06:19:02] [Server thread/INFO]: <Juanetoh> miora
# [06:19:04] [Server thread/INFO]: <Juanetoh> lkos
# [06:19:06] [Server thread/INFO]: <Juanetoh> caballos
# [06:19:11] [Server thread/INFO]: <Juanetoh> lo puedes manejar
# [06:19:14] [Server thread/INFO]: <Juanetoh> esos
# [06:19:17] [Server thread/INFO]: <Juanetoh> son eseuqleot
# [06:19:30] [Server thread/INFO]: <Juanetoh> agarra
# [06:19:31] [Server thread/INFO]: <Juanetoh> el agua
# [06:19:31] [Server thread/INFO]: <Juanetoh> aca
# [06:19:33] [Server thread/INFO]: <Juanetoh> mi amor
# [06:19:38] [Server thread/INFO]: <Juanetoh> ven
# [06:19:44] [Server thread/INFO]: <Juanetoh> amor
# [06:19:45] [Server thread/INFO]: <Juanetoh> aca
# [06:19:45] [Server thread/INFO]: <Juanetoh> veen
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [06:19:52] [Server thread/INFO]: <Juanetoh> veern
# [06:19:56] [Server thread/INFO]: <Juanetoh> amorr
# [06:19:57] [Server thread/INFO]: <Juanetoh> pero
# [06:19:58] [Server thread/INFO]: <Juanetoh> ahi no
# [06:20:22] [Server thread/INFO]: <Juanetoh> a ver guapa
# [06:20:23] [Server thread/INFO]: <Juanetoh> ven
# [06:20:53] [Server thread/INFO]: <Juanetoh> veen
# [06:20:55] [Server thread/INFO]: <Juanetoh> todavía hay cosas
# [06:21:08] [Server thread/INFO]: <Juanetoh> mira
# [06:21:09] [Server thread/INFO]: <Juanetoh> aca
# [06:21:18] [Server thread/INFO]: <Juanetoh> ya tienes tu casco
# [06:21:27] [Server thread/INFO]: <Juanetoh> yha
# [06:21:30] [Server thread/INFO]: <Juanetoh> te lo di
# [06:21:32] [Server thread/INFO]: <Juanetoh> amoor
# [06:22:11] [Server thread/INFO]: <Juanetoh> sipo
# [06:22:14] [Server thread/INFO]: <Juanetoh> uqieres ir a la casa?
# [06:22:16] [Server thread/INFO]: <Juanetoh> o seguir dedscubriendo
# [06:22:51] [Server thread/INFO]: <Juanetoh> comee
# [06:23:21] [Server thread/INFO]: <Juanetoh> pq
# [06:23:23] [Server thread/INFO]: <Juanetoh> son mis cosas
# [06:23:25] [Server thread/INFO]: <Juanetoh> igual
# [06:23:39] [Server thread/INFO]: <Juanetoh> vente
# [06:23:39] [Server thread/INFO]: <Juanetoh> amor
# [06:24:47] [Server thread/INFO]: <Juanetoh> vente
# [06:25:05] [Server thread/INFO]: <Juanetoh> vente a mi yate
# [06:25:08] [Server thread/INFO]: <Juanetoh> es nutra cita romantica
# [06:26:11] [Server thread/INFO]: <Juanetoh> click derecho m iamor
# [06:26:14] [Server thread/INFO]: <Juanetoh> xd
# [06:26:34] [Server thread/INFO]: <Juanetoh> click derecho
# [06:26:42] [Server thread/INFO]: <Juanetoh> hermosa
# [06:26:45] [Server thread/INFO]: <Juanetoh> me encantas
# [06:26:48] [Server thread/INFO]: <Juanetoh> muak<3
# [06:27:01] [Server thread/INFO]: <Juanetoh> *se miomoix d
# [06:28:09] [Server thread/INFO]: <Juanetoh> mira
# [06:28:10] [Server thread/INFO]: <Juanetoh> delfine
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.6016557532478828
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.9896885734625016
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.31508973947825325
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.3082051336445488
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.30090036637992057
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2958675266356181
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2901979744123935
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2840408782483337
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.27957242947016425
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2744936180919524
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.26895359654233175
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2651563546669138
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2607485971662413
# [06:28:13] [Server thread/WARN]: Oak Boat (vehicle of Juanetoh) moved wrongly! 0.2514926867735312
# [06:28:32] [Server thread/INFO]: <Juanetoh> despues nos raptamos unos
# [06:28:33] [Server thread/INFO]: <Juanetoh> y te los quedas
# [06:28:34] [Server thread/INFO]: <Juanetoh> :3
# [06:29:00] [Server thread/INFO]: <Juanetoh> aqui tamos nena
# [06:29:00] [Server thread/INFO]: <Juanetoh> aa
# [06:29:02] [Server thread/INFO]: <Juanetoh> vinieron
# [06:29:26] [Server thread/INFO]: <Juanetoh> esta
# [06:29:27] [Server thread/INFO]: <Juanetoh> guapa
# [06:29:33] [Server thread/INFO]: <Juanetoh> les voy a poner antorchas
# [06:29:34] [Server thread/INFO]: <Juanetoh> aun lado
# [06:29:40] [Server thread/INFO]: <Juanetoh> mira
# [06:29:41] [Server thread/INFO]: <Juanetoh> esas de ahí
# [06:29:44] [Server thread/INFO]: <Juanetoh> click derecho
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [06:30:08] [Server thread/INFO]: <Juanetoh> click derecho guapa
# [06:30:24] [Server thread/INFO]: <Juanetoh> ahoar
# [06:30:25] [Server thread/INFO]: <Juanetoh> ahora
# [06:30:27] [Server thread/INFO]: <Juanetoh> quitate la ropa
# [06:30:33] [Server thread/INFO]: <Juanetoh> te voy a hacer el cuchi cu
# [06:30:40] [Server thread/INFO]: <Juanetoh> XD
# [06:30:43] [Server thread/INFO]: <Juanetoh> XD
# [06:30:45] [Server thread/INFO]: <Juanetoh> jaja
# [06:30:47] [Server thread/INFO]: <Juanetoh> te amo
# [06:30:57] [Server thread/INFO]: <Juanetoh> salud
# [06:30:58] [Server thread/INFO]: <Juanetoh> salud
# [06:31:00] [Server thread/INFO]: <Juanetoh> salud mi amor
# [06:33:01] [Server thread/INFO]: <Juanetoh> 1:32
# [06:33:02] [Server thread/INFO]: <Juanetoh> aay
# [06:33:04] [Server thread/INFO]: <Juanetoh> ya estarde
# [06:34:19] [Server thread/INFO]: <Juanetoh> a
# [06:34:54] [Server thread/INFO]: <Juanetoh> me vas a dejar?
# [06:34:54] [Server thread/INFO]: <Juanetoh> :c
# [06:36:01] [Server thread/INFO]: <Juanetoh> que?
# [06:36:05] [Server thread/INFO]: <Juanetoh> noe scuche
# [06:36:44] [Server thread/INFO]: <Juanetoh> con quien te vas?
# [06:36:45] [Server thread/INFO]: <Juanetoh> pipi
# [06:36:55] [Server thread/INFO]: <Juanetoh> pero quien es unu
# [06:37:07] [Server thread/INFO]: <Juanetoh> yat
# [06:37:10] [Server thread/INFO]: <Juanetoh> xd
# [06:37:13] [Server thread/INFO]: <Juanetoh> pero quien es
# [06:37:28] [Server thread/INFO]: <Juanetoh> no amor
# [06:37:29] [Server thread/INFO]: <Juanetoh> la cara
# [06:37:30] [Server thread/INFO]: <Juanetoh> xd
# [06:37:46] [Server thread/INFO]: <Juanetoh> ya
# [06:38:30] [Server thread/INFO]: <Juanetoh> pero
# [06:38:31] [Server thread/INFO]: <Juanetoh> te pregunte
# [06:38:33] [Server thread/INFO]: <Juanetoh> que quien era
# [06:38:33] [Server thread/INFO]: <Juanetoh> xd
# [06:38:38] [Server thread/INFO]: <Juanetoh> a
# [06:38:39] [Server thread/INFO]: <Juanetoh> pq
# [06:38:55] [Server thread/INFO]: <Juanetoh> pero ps
# [06:38:57] [Server thread/INFO]: <Juanetoh> bueno
# [06:39:01] [Server thread/INFO]: <Juanetoh> tampoco le voy a decir algo
# [06:39:04] [Server thread/INFO]: <Juanetoh> solo quería saber xd
# [06:39:17] [Server thread/INFO]: <Juanetoh> noe s eso amor solo quería saber
# [06:39:21] [Server thread/INFO]: <Juanetoh> tampoco le iba a dedicr algo a ese
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [06:40:34] [Server thread/INFO]: <Juanetoh> si ta bien :c
# [06:41:26] [Server thread/INFO]: <Juanetoh> bueno :c
# [06:45:35] [Server thread/INFO]: <PriscilaAliceMia> donde tas bb?
# [06:46:04] [Server thread/INFO]: <Juanetoh> en la casa
# [06:48:03] [Server thread/INFO]: <PriscilaAliceMia> por cierto ya puede que no tenga nitro de nuevo XDXD por que ya me aviso discord de que mi nitro se vence
# [06:48:21] [Server thread/INFO]: <Juanetoh> hubieras usado el que te ganaste
# [06:48:23] [Server thread/INFO]: <Juanetoh> amor
# [06:48:32] [Server thread/INFO]: <Juanetoh> o no haber sorteado el otro
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:02:47] [Server thread/INFO]: <Juanetoh> correy salta
# [07:03:08] [Server thread/INFO]: <Juanetoh> mira
# [07:03:10] [Server thread/INFO]: <Juanetoh> deesde aqui
# [07:03:18] [Server thread/INFO]: <Juanetoh> desde ahi corre
# [07:03:19] [Server thread/INFO]: <Juanetoh> y salta
# [07:03:23] [Server thread/INFO]: <Juanetoh> es que te falta correr mi amor
# [07:03:31] [Server thread/INFO]: <Juanetoh> emm
# [07:03:35] [Server thread/INFO]: <Juanetoh> es que no te puedo explicar aca
# [07:03:39] [Server thread/INFO]: <Juanetoh> no mevas a entender
# [07:03:45] [Server thread/INFO]: <Juanetoh> ..
# [07:03:48] [Server thread/INFO]: <Juanetoh> no te pognas así
# [07:03:51] [Server thread/INFO]: <Juanetoh> presioanr
# [07:03:52] [Server thread/INFO]: <Juanetoh> ctrl
# [07:03:55] [Server thread/INFO]: <Juanetoh> o el shift creo es
# [07:04:00] [Server thread/INFO]: <Juanetoh> con que letras corres?
# [07:04:02] [Server thread/INFO]: <Juanetoh> andale
# [07:04:07] [Server thread/INFO]: <Juanetoh> presionar el control
# [07:04:14] [Server thread/INFO]: <Juanetoh> y no suletes
# [07:04:15] [Server thread/INFO]: <Juanetoh> y salta
# [07:04:24] [Server thread/INFO]: <Juanetoh> ya lo has hecho
# [07:04:27] [Server thread/INFO]: <Juanetoh> la otra vez te salio
# [07:04:36] [Server thread/INFO]: <Juanetoh> salta
# [07:04:38] [Server thread/INFO]: <Juanetoh> hasta el final
# [07:04:52] [Server thread/INFO]: <Juanetoh> es que
# [07:04:54] [Server thread/INFO]: <Juanetoh> ponte arriba del bloque
# [07:04:55] [Server thread/INFO]: <Juanetoh> amor
# [07:05:02] [Server thread/INFO]: <Juanetoh> siii
# [07:07:57] [Server thread/INFO]: <Juanetoh> que paso mi amor
# [07:08:07] [Server thread/INFO]: <PriscilaAliceMia> me gustas -w-
# [07:08:27] [Server thread/INFO]: <Juanetoh> tambien me gustas <3
# [07:08:39] [Server thread/INFO]: <PriscilaAliceMia> awww mua
# [07:09:01] [Server thread/INFO]: <Juanetoh> ❤
# [07:09:13] [Server thread/INFO]: <Juanetoh> ♥
# [07:09:19] [Server thread/INFO]: <Juanetoh> ❣
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:36:00] [Server thread/INFO]: <Juanetoh> veen
# [07:36:01] [Server thread/INFO]: <Juanetoh> amor
# [07:37:17] [Server thread/INFO]: <PriscilaAliceMia> un enderman :v
# [07:37:39] [Server thread/INFO]: <Juanetoh> amor
# [07:37:40] [Server thread/INFO]: <Juanetoh> muevete
# [07:37:45] [Server thread/INFO]: <Juanetoh> amor
# [07:37:49] [Server thread/INFO]: <Juanetoh> el pto endedrman
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:41:38] [Server thread/INFO]: <PriscilaAliceMia> te amo
# [07:42:02] [Server thread/INFO]: <Juanetoh> tambien te amo
# [07:42:35] [Server thread/INFO]: <Juanetoh> amor
# [07:42:36] [Server thread/INFO]: <Juanetoh> pero no guardaste
# [07:42:39] [Server thread/INFO]: <Juanetoh> vacas
# [07:43:21] [Server thread/INFO]: Juanetoh has made the advancement [Ol' Betsy]
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:50:00] [Server thread/INFO]: <PriscilaAliceMia> muamua
# [07:50:03] [Server thread/INFO]: <Juanetoh> mua
# [07:54:09] [Server thread/INFO]: <PriscilaAliceMia> bb
# [07:54:14] [Server thread/INFO]: <PriscilaAliceMia> vc
# [07:55:30] [Server thread/INFO]: <Juanetoh> voy
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [08:11:53] [Server thread/INFO]: PriscilaAliceMia lost connection: Disconnected
# [08:11:53] [Server thread/INFO]: PriscilaAliceMia left the game
# [08:11:58] [Server thread/INFO]: Juanetoh lost connection: Disconnected
# [08:11:58] [Server thread/INFO]: Juanetoh left the game
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
